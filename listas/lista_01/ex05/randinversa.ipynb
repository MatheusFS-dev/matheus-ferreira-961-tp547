# %%
# !pip install numpy matplotlib
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parametro do numero de amostras
n = 1000

# Gerador por transformacao inversa:
# U ~ Uniforme(0,1) e X = sqrt(U), com suporte em [0,1]
np.random.seed(42)
u = np.random.uniform(0, 1, n)
amostras = np.sqrt(u)

print(f'Foram geradas {n} amostras')
print(f'Minimo: {amostras.min():.4f}')
print(f'Maximo: {amostras.max():.4f}')
print(f'Media simulada: {amostras.mean():.4f}')
print(f'Variancia simulada: {amostras.var():.4f}')

# PDF teorica: f(x) = 2x em [0,1]
x_vals = np.linspace(0, 1, 500)
y_vals = 2 * x_vals

plt.figure(figsize=(9, 5))
plt.hist(amostras, bins=25, density=True, alpha=0.7, label='Simulada')
plt.plot(x_vals, y_vals, color='red', linewidth=2, label='PDF teorica: f(x) = 2x')
plt.xlabel('x')
plt.ylabel('Densidade')
plt.title('Histograma das amostras e PDF teorica')
plt.grid(axis='y', alpha=0.3)
plt.legend()
plt.show()
# Out:
# Foram geradas 1000 amostras pela transformacao inversa.
# Minimo: 0.0681
# Maximo: 0.9999
# Media simulada: 0.6581
# Variancia simulada: 0.0571

# %%
# Parametro do numero de amostras
n = 100000

# Gerador por transformacao inversa:
# U ~ Uniforme(0,1) e X = sqrt(U), com suporte em [0,1]
np.random.seed(42)
u = np.random.uniform(0, 1, n)
amostras = np.sqrt(u)

print(f"Foram geradas {n} amostras")
print(f"Minimo: {amostras.min():.4f}")
print(f"Maximo: {amostras.max():.4f}")
print(f"Media simulada: {amostras.mean():.4f}")
print(f"Variancia simulada: {amostras.var():.4f}")

# PDF teorica: f(x) = 2x em [0,1]
x_vals = np.linspace(0, 1, 500)
y_vals = 2 * x_vals

plt.figure(figsize=(9, 5))
plt.hist(amostras, bins=25, density=True, alpha=0.7, label="Simulada")
plt.plot(x_vals, y_vals, color="red", linewidth=2, label="PDF teorica: f(x) = 2x")
plt.xlabel("x")
plt.ylabel("Densidade")
plt.title("Histograma das amostras e PDF teorica")
plt.grid(axis="y", alpha=0.3)
plt.legend()
plt.show()
# Out:
# Foram geradas 100000 amostras pela transformacao inversa.
# Minimo: 0.0024
# Maximo: 1.0000
# Media simulada: 0.6663
# Variancia simulada: 0.0555
