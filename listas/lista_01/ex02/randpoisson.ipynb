# %%
# !pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np

lambda1=4 #Número médio de requisições
N=100 #Numero de amostras

av=np.array([])
x=np.random.uniform(0,1,N)
for ix in x:
    i = 0
    pr = np.exp(-lambda1)
    F=pr
    while ix>=F:
        pr=lambda1/(i+1)*pr
        F = F + pr
        i = i + 1;
    a1=i
    av=np.append(av,a1)

print(av)
# Out:
# [3. 5. 2. 5. 5. 3. 6. 7. 3. 4. 1. 4. 2. 3. 3. 3. 4. 6. 3. 2. 4. 4. 3. 6.
#  5. 3. 5. 2. 7. 2. 4. 5. 3. 2. 4. 4. 5. 3. 5. 3. 6. 5. 4. 2. 7. 3. 2. 5.
#  3. 3. 4. 3. 4. 1. 5. 5. 6. 5. 4. 5. 3. 3. 1. 2. 7. 5. 5. 2. 4. 7. 3. 5.
#  3. 3. 4. 1. 4. 4. 0. 4. 7. 2. 5. 2. 4. 6. 3. 4. 4. 4. 8. 4. 4. 1. 0. 2.
#  6. 4. 5. 9.]
